# %%
# %matplotlib notebook
from skmultiflow.meta.multi_output_learner import MultiOutputLearner
from skmultiflow.data.multilabel_generator import MultilabelGenerator
from lstm_stream import LSTMMask,EvaluatePrequential
# Out:
# Using TensorFlow backend.
# /home/couedrao/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/couedrao/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/couedrao/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
def demo(output_file=None, n_inst=None):  
    nb_nf=5
    nb_metrics=10
    batch_size = 1
    epochs = 10
    embedding_size = 128
    filters = 64
    kernel_size = 5
    lstm_output_size = nb_nf
    max_features = nb_nf*nb_metrics
    maxlen = max_features
    pool_size = 4

    # Setup the File Stream
    #stream = FileStream("music.csv", 0, 6)
    stream = MultilabelGenerator(n_samples=n_inst+1, n_features=max_features, n_targets=lstm_output_size,                                 n_labels=2, random_state=0)
    stream.prepare_for_use()
    print(stream)
    # Setup the classifier
    #classifier = MultiOutputLearner(SGDClassifier(max_iter=100))
    classifier = MultiOutputLearner(LSTMMask(max_features=max_features, maxlen=maxlen, embedding_size=embedding_size, kernel_size=kernel_size, filters=filters, pool_size=pool_size,
                 lstm_output_size=lstm_output_size, batch_size=batch_size, epochs=epochs))
    print(classifier)
    # Setup the evaluator
    evaluator = EvaluatePrequential(pretrain_size=1000, max_samples=n_inst-1000, batch_size=1, n_wait=200,
                                    max_time=1000, output_file=output_file, show_plot=True,
                                    metrics=['hamming_score','hamming_loss', 'j_index', 'exact_match'])
#n_wait : The number of samples to process between each test. 
#max_samples : The maximum number of samples to process during the evaluation.
#pretrain_size : The number of samples to use to train the model before starting the evaluation. 
#max_time : The maximum duration of the simulation (in seconds).
    # Evaluate
    evaluator.evaluate(stream=stream, model=classifier ,model_names=['RCA'])

# %%
if __name__ == '__main__':
    demo('test_prequential_mol.csv', n_inst=50000,)
# Out:
# MultilabelGenerator(n_features=50, n_labels=2, n_samples=50001, n_targets=5,
#                     random_state=0)
# WARNING:tensorflow:From /home/couedrao/.local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/couedrao/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3135: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Build classifier...
# MultiOutputLearner(base_estimator=LSTMMask(batch_size=1, embedding_size=128,
#                                            epochs=10, filters=64, kernel_size=5,
# ...
